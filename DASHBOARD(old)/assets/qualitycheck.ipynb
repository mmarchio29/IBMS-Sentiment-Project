# %%
import pandas as pd

df = pd.read_csv('QuestromSA_final.csv')

# %%
df.head()
# Out:
#                                                Title       Date  \
# 0  Already Posturing About the Performance of the...  9/26/1990
# 1  The entrepreneurial middle class in Nova Scoti...   1/1/1993
# 2  The entrepreneurial middle class in Nova Scoti...   1/1/1993
# 3  Finding our way out of the causation jungle in...   1/1/1993
# 4  Ivan Svitlychnyi's poetry of incarceration: To...   1/1/2005
#
#               Source Type                  Publication Title Publisher City  \
# 0   Historical Newspapers       The Washington Post  (1974-)     Washington
# 1  Dissertations & Theses  ProQuest Dissertations and Theses      Ann Arbor
# 2  Dissertations & Theses  ProQuest Dissertations and Theses      Ann Arbor
# 3  Dissertations & Theses  ProQuest Dissertations and Theses      Ann Arbor
# 4  Dissertations & Theses  ProQuest Dissertations and Theses      Ann Arbor
#
#   Publisher Province     Keyword     Anger   Disgust      Fear  Happiness  \
# ...

# %%
df.shape
# Out:
# (963438, 16)

# %%
df.Keyword.value_counts()
# Out:
# Capitalism    274663
# Capitalist    239237
# Socialist     213542
# Socialism     119400
# Communism     116596
# Name: Keyword, dtype: int64

# %%
df.isnull().sum()
# Out:
# Title                 29738
# Date                  29734
# Source Type           29734
# Publication Title     29734
# Publisher City        29753
# Publisher Province    81676
# Keyword                   0
# Anger                     0
# Disgust                   0
# Fear                      0
# Happiness                 0
# Love                      0
# Neutral                   0
# Other                     0
# Sadness                   0
# Surprise                  0
# dtype: int64

# %%
print(df.loc[df['Keyword'] == 'Socialist'].shape)
df.loc[df['Keyword'] == 'Socialist'].isnull().sum()
# Out:
# (213542, 16)
# Title                  6445
# Date                   6443
# Source Type            6443
# Publication Title      6443
# Publisher City         6443
# Publisher Province    25227
# Keyword                   0
# Anger                     0
# Disgust                   0
# Fear                      0
# Happiness                 0
# Love                      0
# Neutral                   0
# Other                     0
# Sadness                   0
# Surprise                  0
# dtype: int64

# %%
print(df.loc[df['Keyword'] == 'Socialism'].shape)
df.loc[df['Keyword'] == 'Socialism'].isnull().sum()
# Out:
# (119400, 16)
# Title                   31
# Date                    29
# Source Type             29
# Publication Title       29
# Publisher City          29
# Publisher Province    5547
# Keyword                  0
# Anger                    0
# Disgust                  0
# Fear                     0
# Happiness                0
# Love                     0
# Neutral                  0
# Other                    0
# Sadness                  0
# Surprise                 0
# dtype: int64

# %%
print(df.loc[df['Keyword'] == 'Capitalist'].shape)
df.loc[df['Keyword'] == 'Capitalist'].isnull().sum()
# Out:
# (239237, 16)
# Title                 20084
# Date                  20084
# Source Type           20084
# Publication Title     20084
# Publisher City        20084
# Publisher Province    27722
# Keyword                   0
# Anger                     0
# Disgust                   0
# Fear                      0
# Happiness                 0
# Love                      0
# Neutral                   0
# Other                     0
# Sadness                   0
# Surprise                  0
# dtype: int64

# %%
print(df.loc[df['Keyword'] == 'Capitalism'].shape)
df.loc[df['Keyword'] == 'Capitalism'].isnull().sum()
# Out:
# (274663, 16)
# Title                  3178
# Date                   3178
# Source Type            3178
# Publication Title      3178
# Publisher City         3197
# Publisher Province    17948
# Keyword                   0
# Anger                     0
# Disgust                   0
# Fear                      0
# Happiness                 0
# Love                      0
# Neutral                   0
# Other                     0
# Sadness                   0
# Surprise                  0
# dtype: int64

# %%
print(df.loc[df['Keyword'] == 'Communism'].shape)
df.loc[df['Keyword'] == 'Communism'].isnull().sum()
# Out:
# (116596, 16)
# Title                    0
# Date                     0
# Source Type              0
# Publication Title        0
# Publisher City           0
# Publisher Province    5232
# Keyword                  0
# Anger                    0
# Disgust                  0
# Fear                     0
# Happiness                0
# Love                     0
# Neutral                  0
# Other                    0
# Sadness                  0
# Surprise                 0
# dtype: int64

# %%
df['Year'] = pd.to_datetime(df['Date'], errors='coerce').dt.year
df['Year'].unique()
# Out:
# array([1990., 1993., 2005., 1995., 2008., 1983., 1985., 2009., 1977.,
#        1989., 2010., 1970., 1992., 1982., 1978., 1996., 1972., 1988.,
#        1980., 1981., 1984., 1991., 1986., 1994., 1955., 1979., 1956.,
#        1971., 1957., 1997., 1976., 2000., 2001., 2002., 2003., 2004.,
#        2006., 1930., 1931., 1932., 1923., 1933., 1934., 1935., 1936.,
#        1937., 1938., 1939., 1924., 1925., 1926., 1927., 1929., 1940.,
#        1941., 1949.,   nan, 1942., 1943., 1944., 1945., 1946., 1947.,
#        1948., 1998., 1999., 1987., 1950., 1951., 1952., 1953., 1954.,
#        1958., 1959., 1960., 1961., 1964., 1962., 1963., 1965., 1966.,
#        1967., 1968., 1969., 1973., 1974., 1975., 1878., 1879., 1880.,
#        1877., 1881., 1882., 1883., 1884., 1885., 1886., 1887., 1888.,
#        1889., 1890., 1891., 1892., 1893., 1894., 1895., 1896., 1897.,
#        1898., 1899., 1900., 1901., 1902., 1903., 1904., 1905., 1906.,
# ...

# %%
df.loc[df.Year==2025.0]
# Out:
#                                                     Title      Date  \
# 938938  A Psychological Theory for Accountability/Canc...  1/1/2025
#
#                    Source Type                  Publication Title  \
# 938938  Dissertations & Theses  ProQuest Dissertations and Theses
#
#        Publisher City Publisher Province     Keyword     Anger   Disgust  \
# 938938      Ann Arbor                 MI  Capitalism  0.131612  0.159949
#
#             Fear  Happiness      Love   Neutral     Other   Sadness  Surprise  \
# 938938  0.043621   0.122993  0.025005  0.113046  0.057492  0.035508  0.310775
#
#           Year
# 938938  2025.0

# %%
grouped_df = df.groupby(['Keyword', 'Year']).mean().reset_index()
grouped_df
# Out:
# /var/folders/h_/lxrkd3yx3w11tnfvg06j7l140000gn/T/ipykernel_83060/512813548.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df = df.groupby(['Keyword', 'Year']).mean().reset_index()
#         Keyword    Year     Anger   Disgust      Fear  Happiness      Love  \
# 0    Capitalism  1890.0  0.048409  0.142586  0.076979   0.020855  0.016991
# 1    Capitalism  1900.0  0.113937  0.108974  0.056634   0.088646  0.045259
# 2    Capitalism  1903.0  0.081226  0.065837  0.037990   0.107270  0.057996
# 3    Capitalism  1904.0  0.229858  0.129507  0.073176   0.215190  0.029564
# 4    Capitalism  1905.0  0.192343  0.181543  0.059488   0.154898  0.020412
# ..          ...     ...       ...       ...       ...        ...       ...
# ...

# %%
grouped_df['Sum'] = grouped_df.loc[:, 'Anger':'Surprise'].sum(axis=1)
grouped_df
# Out:
#         Keyword    Year     Anger   Disgust      Fear  Happiness      Love  \
# 0    Capitalism  1890.0  0.048409  0.142586  0.076979   0.020855  0.016991
# 1    Capitalism  1900.0  0.113937  0.108974  0.056634   0.088646  0.045259
# 2    Capitalism  1903.0  0.081226  0.065837  0.037990   0.107270  0.057996
# 3    Capitalism  1904.0  0.229858  0.129507  0.073176   0.215190  0.029564
# 4    Capitalism  1905.0  0.192343  0.181543  0.059488   0.154898  0.020412
# ..          ...     ...       ...       ...       ...        ...       ...
# 681   Socialist  2020.0  0.114545  0.115430  0.060874   0.123700  0.040896
# 682   Socialist  2021.0  0.094881  0.118782  0.057635   0.125932  0.041444
# 683   Socialist  2022.0  0.110990  0.116512  0.059190   0.120567  0.039679
# 684   Socialist  2023.0  0.111020  0.120503  0.059931   0.119685  0.040253
# 685   Socialist  2024.0  0.117037  0.121994  0.062729   0.120254  0.040403
#
#       Neutral     Other   Sadness  Surprise  Sum
# ...

# %%
grouped_df['Positive'] = grouped_df[['Happiness', 'Love', 'Surprise']].sum(axis=1)
grouped_df['Negative'] = grouped_df[['Anger', 'Disgust', 'Fear', 'Sadness']].sum(axis=1)
grouped_df
# Out:
#         Keyword    Year     Anger   Disgust      Fear  Happiness      Love  \
# 0    Capitalism  1890.0  0.048409  0.142586  0.076979   0.020855  0.016991
# 1    Capitalism  1900.0  0.113937  0.108974  0.056634   0.088646  0.045259
# 2    Capitalism  1903.0  0.081226  0.065837  0.037990   0.107270  0.057996
# 3    Capitalism  1904.0  0.229858  0.129507  0.073176   0.215190  0.029564
# 4    Capitalism  1905.0  0.192343  0.181543  0.059488   0.154898  0.020412
# ..          ...     ...       ...       ...       ...        ...       ...
# 681   Socialist  2020.0  0.114545  0.115430  0.060874   0.123700  0.040896
# 682   Socialist  2021.0  0.094881  0.118782  0.057635   0.125932  0.041444
# 683   Socialist  2022.0  0.110990  0.116512  0.059190   0.120567  0.039679
# 684   Socialist  2023.0  0.111020  0.120503  0.059931   0.119685  0.040253
# 685   Socialist  2024.0  0.117037  0.121994  0.062729   0.120254  0.040403
#
#       Neutral     Other   Sadness  Surprise  Sum  Positive  Negative
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
grouped_df.loc[grouped_df.Keyword == 'Capitalism'][['Keyword', 'Year', 'Positive', 'Negative']]
# Out:
#         Keyword    Year  Positive  Negative
# 0    Capitalism  1890.0  0.149972  0.431599
# 1    Capitalism  1900.0  0.272161  0.338970
# 2    Capitalism  1903.0  0.391824  0.202209
# 3    Capitalism  1904.0  0.286733  0.460680
# 4    Capitalism  1905.0  0.318716  0.473229
# 5    Capitalism  1907.0  0.353326  0.166110
# 6    Capitalism  1908.0  0.244151  0.425546
# 7    Capitalism  1909.0  0.258585  0.396518
# 8    Capitalism  1912.0  0.254279  0.450217
# 9    Capitalism  1913.0  0.329730  0.390039
# 10   Capitalism  1914.0  0.190650  0.322354
# 11   Capitalism  1917.0  0.235347  0.314660
# 12   Capitalism  1918.0  0.286704  0.403655
# 13   Capitalism  1919.0  0.285331  0.333998
# 14   Capitalism  1920.0  0.221830  0.380792
# 15   Capitalism  1921.0  0.196402  0.452417
# 16   Capitalism  1922.0  0.198840  0.385539
# 17   Capitalism  1923.0  0.287009  0.363875
# 18   Capitalism  1924.0  0.230309  0.415938
# 19   Capitalism  1925.0  0.238247  0.444457
# ...

# %%
keyword_count = df.groupby('Title')['Keyword'].nunique().reset_index()
keyword_count.columns = ['Title', 'Unique_Keywords']

# %%
keyword_count.shape
# Out:
# (492441, 2)

# %%
keyword_count.Unique_Keywords.value_counts()
# Out:
# 1    271030
# 2    105031
# 3     52261
# 4     34784
# 5     29335
# Name: Unique_Keywords, dtype: int64

# %%
import pandas as pd
from itertools import combinations
from collections import Counter

# Group by 'Title' and aggregate 'Keyword' into lists
grouped = df.groupby('Title')['Keyword'].apply(list).reset_index()

# Generate all unique pairs of keywords for each title
pair_counts = Counter()
for keywords in grouped['Keyword']:
    if len(keywords) > 1:
        pairs = combinations(sorted(keywords), 2)
        pair_counts.update(pairs)

# Convert the pair counts to a DataFrame
pair_counts_df = pd.DataFrame(pair_counts.items(), columns=['Keyword_Pair', 'Count'])

# Display the result
print(pair_counts_df)
# Out:
#                 Keyword_Pair   Count
# 0   (Capitalism, Capitalist)  150951
# 1    (Capitalism, Communism)   74842
# 2    (Capitalism, Socialism)   81861
# 3    (Capitalism, Socialist)  124199
# 4    (Capitalist, Communism)   67915
# 5    (Capitalist, Socialism)   72615
# 6    (Capitalist, Socialist)  122151
# 7     (Communism, Socialism)   57396
# 8     (Communism, Socialist)  121508
# 9     (Socialism, Socialist)  109223
# 10    (Socialism, Socialism)    3341
# 11  (Capitalism, Capitalism)   10356
# 12  (Capitalist, Capitalist)   10869
# 13    (Socialist, Socialist)  205043
# 14    (Communism, Communism)   11379

# %%
single_keyword_titles = keyword_count[keyword_count['Unique_Keywords'] == 1]

# Merge the original DataFrame with the filtered titles
filtered_df = df[df['Title'].isin(single_keyword_titles['Title'])]

# Display the result
filtered_df.head()
# Out:
#                                                Title       Date  \
# 0  Already Posturing About the Performance of the...  9/26/1990
# 3  Finding our way out of the causation jungle in...   1/1/1993
# 4  Ivan Svitlychnyi's poetry of incarceration: To...   1/1/2005
# 5      The impact of NAFTA on transborder data flows   1/1/1995
# 8  User fees for residential waste disposal: Issu...   1/1/1993
#
#               Source Type                  Publication Title Publisher City  \
# 0   Historical Newspapers       The Washington Post  (1974-)     Washington
# 3  Dissertations & Theses  ProQuest Dissertations and Theses      Ann Arbor
# 4  Dissertations & Theses  ProQuest Dissertations and Theses      Ann Arbor
# 5  Dissertations & Theses  ProQuest Dissertations and Theses      Ann Arbor
# 8  Dissertations & Theses  ProQuest Dissertations and Theses      Ann Arbor
#
#   Publisher Province     Keyword     Anger   Disgust      Fear  Happiness  \
# ...

# %%
filtered_df.Keyword.value_counts()
# Out:
# Capitalism    95081
# Socialist     75212
# Capitalist    54795
# Communism     30936
# Socialism     18261
# Name: Keyword, dtype: int64

# %%
grouped_filtered_df = filtered_df.groupby(['Keyword', 'Year']).mean().reset_index()
grouped_filtered_df.head()
# Out:
# /var/folders/h_/lxrkd3yx3w11tnfvg06j7l140000gn/T/ipykernel_83060/3558067917.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_filtered_df = filtered_df.groupby(['Keyword', 'Year']).mean().reset_index()
#       Keyword    Year     Anger   Disgust      Fear  Happiness      Love  \
# 0  Capitalism  1890.0  0.048409  0.142586  0.076979   0.020855  0.016991
# 1  Capitalism  1900.0  0.120580  0.098396  0.055503   0.111101  0.053620
# 2  Capitalism  1903.0  0.081226  0.065837  0.037990   0.107270  0.057996
# 3  Capitalism  1908.0  0.223931  0.128232  0.110402   0.075760  0.022386
# 4  Capitalism  1909.0  0.048409  0.142586  0.076979   0.020855  0.016991
#
#     Neutral     Other   Sadness  Surprise
# 0  0.328366  0.090062  0.163625  0.112126
# 1  0.224308  0.137732  0.031449  0.167311
# ...

# %%
grouped_filtered_df.Keyword.value_counts()
# Out:
# Socialist     145
# Socialism     141
# Capitalist    137
# Communism     124
# Capitalism    111
# Name: Keyword, dtype: int64

# %%
grouped_filtered_df['Sum'] = grouped_filtered_df.loc[:, 'Anger':'Surprise'].sum(axis=1)
grouped_filtered_df.head()
# Out:
#       Keyword    Year     Anger   Disgust      Fear  Happiness      Love  \
# 0  Capitalism  1890.0  0.048409  0.142586  0.076979   0.020855  0.016991
# 1  Capitalism  1900.0  0.120580  0.098396  0.055503   0.111101  0.053620
# 2  Capitalism  1903.0  0.081226  0.065837  0.037990   0.107270  0.057996
# 3  Capitalism  1908.0  0.223931  0.128232  0.110402   0.075760  0.022386
# 4  Capitalism  1909.0  0.048409  0.142586  0.076979   0.020855  0.016991
#
#     Neutral     Other   Sadness  Surprise  Sum
# 0  0.328366  0.090062  0.163625  0.112126  1.0
# 1  0.224308  0.137732  0.031449  0.167311  1.0
# 2  0.334054  0.071914  0.017156  0.226558  1.0
# 3  0.161810  0.133654  0.039231  0.104594  1.0
# 4  0.328366  0.090062  0.163625  0.112126  1.0

# %%
grouped_filtered_df['Positive'] = grouped_filtered_df[['Happiness', 'Love', 'Surprise']].sum(axis=1)
grouped_filtered_df['Negative'] = grouped_filtered_df[['Anger', 'Disgust', 'Fear', 'Sadness']].sum(axis=1)
grouped_filtered_df.head()
# Out:
#       Keyword    Year     Anger   Disgust      Fear  Happiness      Love  \
# 0  Capitalism  1890.0  0.048409  0.142586  0.076979   0.020855  0.016991
# 1  Capitalism  1900.0  0.120580  0.098396  0.055503   0.111101  0.053620
# 2  Capitalism  1903.0  0.081226  0.065837  0.037990   0.107270  0.057996
# 3  Capitalism  1908.0  0.223931  0.128232  0.110402   0.075760  0.022386
# 4  Capitalism  1909.0  0.048409  0.142586  0.076979   0.020855  0.016991
#
#     Neutral     Other   Sadness  Surprise  Sum  Positive  Negative
# 0  0.328366  0.090062  0.163625  0.112126  1.0  0.149972  0.431599
# 1  0.224308  0.137732  0.031449  0.167311  1.0  0.332033  0.305928
# 2  0.334054  0.071914  0.017156  0.226558  1.0  0.391824  0.202209
# 3  0.161810  0.133654  0.039231  0.104594  1.0  0.202741  0.501795
# 4  0.328366  0.090062  0.163625  0.112126  1.0  0.149972  0.431599

# %% [markdown]
# ## One with the marker o is the graph using the independent documents

# %% [markdown]
# #### Communism Positive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(30, 8))
sns.lineplot(data=grouped_filtered_df.loc[grouped_filtered_df.Keyword == 'Communism'], x='Year', y='Positive', marker='o')
sns.lineplot(data=grouped_df.loc[grouped_df.Keyword == 'Communism'], x='Year', y='Positive')

plt.title('Positive Sentiment Trends from 1890 to 1960')
plt.xlabel('Year')
plt.ylabel('Sentiment Score')
plt.legend(title='Keyword')
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #### Capitalism Positive

# %%
plt.figure(figsize=(30, 8))
sns.lineplot(data=grouped_filtered_df.loc[grouped_filtered_df.Keyword == 'Capitalism'], x='Year', y='Positive', marker='o')
sns.lineplot(data=grouped_df.loc[grouped_df.Keyword == 'Capitalism'], x='Year', y='Positive')

plt.title('Positive Sentiment Trends from 1890 to 1960')
plt.xlabel('Year')
plt.ylabel('Sentiment Score')
plt.legend(title='Keyword')
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #### Socialism Positive

# %%
plt.figure(figsize=(30, 8))
sns.lineplot(data=grouped_filtered_df.loc[grouped_filtered_df.Keyword == 'Socialism'], x='Year', y='Positive', marker='o')
sns.lineplot(data=grouped_df.loc[grouped_df.Keyword == 'Socialism'], x='Year', y='Positive')

plt.title('Positive Sentiment Trends from 1890 to 1960')
plt.xlabel('Year')
plt.ylabel('Sentiment Score')
plt.legend(title='Keyword')
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #### All Positive (New Independent Data)

# %%
plt.figure(figsize=(30, 8))
sns.lineplot(data=grouped_filtered_df, x='Year', y='Positive', hue='Keyword', marker='o')

plt.title('Positive Sentiment Trends from 1890 to 1960')
plt.xlabel('Year')
plt.ylabel('Sentiment Score')
plt.legend(title='Keyword')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(30, 8))
sns.lineplot(data=grouped_filtered_df.loc[(grouped_filtered_df.Year > 1980) & (grouped_filtered_df.Year < 2020)], x='Year', y='Positive', hue='Keyword', marker='o')

plt.title('Positive Sentiment Trends from 1890 to 1960')
plt.xlabel('Year')
plt.ylabel('Sentiment Score')
plt.legend(title='Keyword')
plt.grid(True)
plt.show()

# %% [markdown]
# #### OLD DATA

# %%
plt.figure(figsize=(30, 8))
sns.lineplot(data=grouped_df.loc[(grouped_df.Year > 1980) & (grouped_df.Year < 2020)], x='Year', y='Positive', hue='Keyword', marker='o')

plt.title('Positive Sentiment Trends from 1890 to 1960')
plt.xlabel('Year')
plt.ylabel('Sentiment Score')
plt.legend(title='Keyword')
plt.grid(True)
plt.show()
